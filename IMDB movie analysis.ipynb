# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/imdb_top_1000.csv")
df.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# ...

# %% [raw]
# df.info()

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (714, 16)

# %%
df.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    object
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 94.8+ KB

# %%
df['Runtime'] = df['Runtime'].astype(str).str.replace("min", "", regex=False).str.strip()
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce')

# %%
df['Gross'] = df['Gross'].astype(str)
df['Gross'] = df['Gross'].str.replace(r'[\$,M]', '', regex=True).str.strip()
print(df[df['Gross'].str.contains('[^0-9.]', na=False)][['Series_Title', 'Gross']].head(20))
# Out:
# Empty DataFrame
# Columns: [Series_Title, Gross]
# Index: []

# %%
df['Gross'] = df['Gross'].str.replace(',', '')
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    int64
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    int64
# dtypes: float64(2), int64(3), object(11)
# memory usage: 94.8+ KB

# %%
df.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A      142         Drama
# 1             The Godfather          1972           A      175  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes      Gross
# 0  William Sadler      2343110   28341469
# ...

# %% [markdown]
# # Top 10 highest-rated movies

# %%
df.sort_values(by = 'IMDB_Rating', ascending = False).head(10)
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
#
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# ...

# %% [markdown]
# # Show top 5 highest-grossing movies

# %%
df.sort_values(by = 'Gross', ascending = False).head(5)
# Out:
#                                            Poster_Link  \
# 477  https://m.media-amazon.com/images/M/MV5BOTAzOD...
# 59   https://m.media-amazon.com/images/M/MV5BMTc5MD...
# 623  https://m.media-amazon.com/images/M/MV5BMTYwOT...
# 60   https://m.media-amazon.com/images/M/MV5BMjMxNj...
# 652  https://m.media-amazon.com/images/M/MV5BMDdmZG...
#
#                                    Series_Title Released_Year Certificate  \
# 477  Star Wars: Episode VII - The Force Awakens          2015           U
# 59                            Avengers: Endgame          2019          UA
# 623                                      Avatar          2009          UA
# 60                       Avengers: Infinity War          2018          UA
# 652                                     Titanic          1997          UA
#
#      Runtime                       Genre  IMDB_Rating  \
# 477      138   Action, Adventure, Sci-Fi          7.9
# 59       181    Action, Adventure, Drama          8.4
# ...

# %% [markdown]
# # Count of Movies per Genre

# %%
df['Main_Genre'] = df['Genre'].str.split(",").str[0]
plt.figure(figsize=(12,6))
sns.countplot(data = df, x = 'Main_Genre', palette = 'viridis', order = df['Main_Genre'].value_counts().index)
plt.title("Movie Count per Genre")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10988\1665947969.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = df, x = 'Main_Genre', palette = 'viridis', order = df['Main_Genre'].value_counts().index)

# %% [markdown]
# # Trend of IMDB ratings over the years

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 997
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    int64
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    int64
#  16  Main_Genre     714 non-null    object
# ...

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors = 'coerce')
ratings_by_year = df.groupby('Released_Year')['IMDB_Rating'].mean().reset_index()
plt.figure(figsize=(12,6))
sns.lineplot(data = ratings_by_year, x = 'Released_Year', y = 'IMDB_Rating')
plt.title('Average IMDB Rating over the Years')
plt.xlabel('Year')
plt.ylabel('Rating')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Average Runtime by Genre

# %%
df.groupby('Main_Genre')['Runtime'].mean().sort_values(ascending = False).head(10)
# Out:
# Main_Genre
# Western      148.250000
# Biography    135.000000
# Adventure    134.172414
# Crime        129.270270
# Action       128.377953
# Drama        127.260417
# Mystery      122.000000
# Comedy       109.451923
# Family       107.500000
# Horror       106.222222
# Name: Runtime, dtype: float64

# %% [markdown]
# # Top 10 most frequent directors in the top 100

# %%
top_directors = df['Director'].value_counts(ascending = False).head(10)
print(top_directors)
# Out:
# Director
# Steven Spielberg     13
# Martin Scorsese      10
# Alfred Hitchcock      9
# Christopher Nolan     8
# Clint Eastwood        8
# Quentin Tarantino     8
# David Fincher         8
# Hayao Miyazaki        7
# Rob Reiner            7
# Woody Allen           7
# Name: count, dtype: int64
